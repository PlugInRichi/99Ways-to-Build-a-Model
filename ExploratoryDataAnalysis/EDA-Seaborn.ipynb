# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from vega_datasets import data

# %% [markdown]
# # Seaborn exploration

# %%
sns.set_style("dark")
plt.figure(figsize=(20, 10))
sns.pairplot(cars)

# %% [markdown]
# Es posible separar los datos utilizando variables categóricas de los registros

# %%
plt.figure(figsize=(20, 10))
sns.pairplot(cars, hue='Origin', diag_kind='hist')

# %% [markdown]
# Otra forma alternativa de presentar los datos s utilizando la distribución marginal en la diagonal de la matriz y graficando una función de regresión para cada una de las correlaciones

# %%
plt.figure(figsize=(20, 10))
sns.pairplot(cars, diag_kind='kde', kind='reg', hue='Origin')

# %% [markdown]
# Incluso podemos utilizar un mapa de calor para represnetar la fuerza d elas correlaciones entre las variables así como su tipo

# %%
plt.figure(figsize=(15, 12))
sns.heatmap(cars.corr(), annot=True, cmap="coolwarm")
# Out:
# <AxesSubplot:>
